# %%
import math

# %% [markdown]
# ## Strings

# %% [markdown]
# ### Slicing

# %%
name = "My name is Goh Kok Hong"

# %%
name[0]
# Out:
# 'M'

# %%
name[1]
# Out:
# 'y'

# %%
name[0:7]
# Out:
# 'My name'

# %%
name[:7]
# Out:
# 'My name'

# %%
name[11:]
# Out:
# 'Goh Kok Hong'

# %%
myList = [1,2,3,4,5]

# %%
myList[2:4]
# Out:
# [3, 4]

# %% [markdown]
# ### Formatting

# %%
"My number is: " + str(5)
# Out:
# 'My number is: 5'

# %%
f'My number is: {5}'
# Out:
# 'My number is: 5'

# %%
f'My number os: {5} and twice that is {2*5}'
# Out:
# 'My number os: 5 and twice that is 10'

# %%
f'Pi is: {math.pi:.2f}'
# Out:
# 'Pi is: 3.14'

# %%
'Pi is: {}'.format(math.pi)
# Out:
# 'Pi is: 3.141592653589793'

# %% [markdown]
# ### Multi-line Strings

# %%
myString = '''
Here is a long block of text
I can add new lines!
The text doesn't stop until it sees \'\'\'
'''

myString
# Out:
# "\nHere is a long block of text\nI can add new lines!\nThe text doesn't stop until it sees '''\n"

# %%
print(myString)
# Out:
# Here is a long block of text
# I can add new lines!
# The text doesn't stop until it sees '''
