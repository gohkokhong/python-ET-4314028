# %% [markdown]
# ## Sets

# %%
mySet = {'a', 'b', 'c' }
mySet
# Out:
# {'a', 'b', 'c'}

# %%
mySet = set(('a', 'b', 'c'))
mySet
# Out:
# {'a', 'b', 'c'}

# %%
myList = ['a', 'b', 'b', 'c', 'd', 'e', 'e', 'e']
myList = list(set(myList))
myList
# Out:
# ['b', 'c', 'a', 'd', 'e']

# %%
mySet[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 mySet[0]
#
# TypeError: 'set' object is not subscriptable

# %%
number = 1
1[0]
# Out:
# <>:2: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
# /var/folders/w9/1hcykmy94pbddll0cs3dv9tc0000gn/T/ipykernel_84334/2203923273.py:2: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
#   1[0]
# /var/folders/w9/1hcykmy94pbddll0cs3dv9tc0000gn/T/ipykernel_84334/2203923273.py:2: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
#   1[0]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 number = 1
# ----> 2 1[0]
#
# TypeError: 'int' object is not subscriptable

# %%
mySet.add('d')
mySet
# Out:
# {'a', 'b', 'c', 'd'}

# %%
'a' in mySet
# Out:
# True

# %%
'z' in mySet
# Out:
# False

# %%
len(mySet)
# Out:
# 4

# %%
while len(mySet):
    print(mySet.pop())
# Out:
# d
# b
# c
# a

# %%
mySet = {'a', 'b', 'c' }

# %%
mySet.discard('a')

# %%
print(mySet)
# Out:
# {'b', 'c'}

# %% [markdown]
# ## Tuples

# %%
myTuple = ('a', 'b', 'c')
myTuple
# Out:
# ('a', 'b', 'c')

# %%
myTuple[0]
# Out:
# 'a'

# %%
myTuple[0] = 'd'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 myTuple[0] = 'd'
#
# TypeError: 'tuple' object does not support item assignment

# %%
def returnsMultipleValues():
    return 1,2,3

type(returnsMultipleValues())
# Out:
# tuple

# %%
myTuple = 1, 2, 3

# %%
myTuple
# Out:
# (1, 2, 3)

# %%
a, b, c = returnsMultipleValues()
print(a)
print(b)
print(c)
# Out:
# 1
# 2
# 3
