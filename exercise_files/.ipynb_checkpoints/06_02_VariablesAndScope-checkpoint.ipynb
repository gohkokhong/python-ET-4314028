# %% [markdown]
# ## Function Scope

# %%
def performOperation(*args, **kwargs):
    print(args)
    print(kwargs)

performOperation(1, 2, operation='sum')
# Out:
# (1, 2)
# {'operation': 'sum'}

# %% [markdown]
# ### locals()

# %%
def performOperation(num1, num2, operation='sum'):
    print(locals())

performOperation(1, 2, operation='multiply')
# Out:
# {'num1': 1, 'num2': 2, 'operation': 'multiply'}

# %% [markdown]
# ### globals()

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   "def performOperation(*args, **kwargs):\n    print(args)\n    print(kwargs)\n\nperformOperation(1, 2, operation='sum')",
#   "def performOperation(num1, num2, operation='sum'):\n    print(locals())\n\nperformOperation(1, 2, operation='multiply')",
#   "def performOperation(num1, num2, operation='sum'):\n    print(locals())\n\nperformOperation(1, 2, operation='multiply')",
#   'globals()'],
#  '_oh': {},
#  '_dh': [PosixPath('/Users/gohkokhong/Documents/GitHub/python-ET-4314028/exercise_files')],
#  'In': ['',
#   "def performOperation(*args, **kwargs):\n    print(args)\n    print(kwargs)\n\nperformOperation(1, 2, operation='sum')",
#   "def performOperation(num1, num2, operation='sum'):\n    print(locals())\n\nperformOperation(1, 2, operation='multiply')",
#   "def performOperation(num1, num2, operation='sum'):\n    print(locals())\n\nperformOperation(1, 2, operation='multiply')",
#   'globals()'],
#  'Out': {},
#  'get_ipython': <function IPython.core.getipython.get_ipython()>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x107e1d400>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x107e1d400>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': '',
#  '__': '',
#  '___': '',
#  '__session__': '/Users/gohkokhong/Documents/GitHub/python-ET-4314028/exercise_files/06_02_VariablesAndScope.ipynb',
#  'json': <module 'json' from '/opt/homebrew/anaconda3/lib/python3.13/json/__init__.py'>,
#  'sys': <module 'sys' (built-in)>,
#  '__import__': <function _frozen_importlib.__import__(name, globals=None, locals=None, fromlist=(), level=0)>,
#  'islice': itertools.islice,
#  'collections': <module 'collections' from '/opt/homebrew/anaconda3/lib/python3.13/collections/__init__.py'>,
#  'NamespaceMagics': IPython.core.magics.namespace.NamespaceMagics,
#  '_jupyterlab_variableinspector_nms': <IPython.core.magics.namespace.NamespaceMagics at 0x107e096d0>,
#  '_jupyterlab_variableinspector_Jupyter': <ipykernel.zmqshell.ZMQInteractiveShell at 0x107be0c20>,
#  '_jupyterlab_variableinspector_maxitems': 10,
#  '__np': None,
#  '__pd': None,
#  '__pyspark': None,
#  '__tf': None,
#  '__K': None,
#  '__torch': None,
#  '__ipywidgets': None,
#  '__xr': None,
#  '_attempt_import': <function __main__._attempt_import(module)>,
#  '_check_imported': <function __main__._check_imported()>,
#  '_jupyterlab_variableinspector_changesettings': <function __main__._jupyterlab_variableinspector_changesettings(maxitems, **kwargs)>,
#  '_jupyterlab_variableinspector_getsizeof': <function __main__._jupyterlab_variableinspector_getsizeof(x)>,
#  '_jupyterlab_variableinspector_getshapeof': <function __main__._jupyterlab_variableinspector_getshapeof(x)>,
#  '_jupyterlab_variableinspector_getcontentof': <function __main__._jupyterlab_variableinspector_getcontentof(x)>,
#  '_jupyterlab_variableinspector_is_matrix': <function __main__._jupyterlab_variableinspector_is_matrix(x)>,
#  '_jupyterlab_variableinspector_is_widget': <function __main__._jupyterlab_variableinspector_is_widget(x)>,
#  '_jupyterlab_variableinspector_dict_list': <function __main__._jupyterlab_variableinspector_dict_list()>,
#  '_jupyterlab_variableinspector_getmatrixcontent': <function __main__._jupyterlab_variableinspector_getmatrixcontent(x, max_rows=10000)>,
#  '_jupyterlab_variableinspector_displaywidget': <function __main__._jupyterlab_variableinspector_displaywidget(widget)>,
#  '_jupyterlab_variableinspector_default': <function __main__._jupyterlab_variableinspector_default(o)>,
#  '_jupyterlab_variableinspector_deletevariable': <function __main__._jupyterlab_variableinspector_deletevariable(x)>,
#  '_i': "def performOperation(num1, num2, operation='sum'):\n    print(locals())\n\nperformOperation(1, 2, operation='multiply')",
#  '_ii': "def performOperation(num1, num2, operation='sum'):\n    print(locals())\n\nperformOperation(1, 2, operation='multiply')",
#  '_iii': "def performOperation(*args, **kwargs):\n    print(args)\n    print(kwargs)\n\nperformOperation(1, 2, operation='sum')",
#  '_i1': "def performOperation(*args, **kwargs):\n    print(args)\n    print(kwargs)\n\nperformOperation(1, 2, operation='sum')",
#  'performOperation': <function __main__.performOperation(num1, num2, operation='sum')>,
#  '_i2': "def performOperation(num1, num2, operation='sum'):\n    print(locals())\n\nperformOperation(1, 2, operation='multiply')",
#  '_i3': "def performOperation(num1, num2, operation='sum'):\n    print(locals())\n\nperformOperation(1, 2, operation='multiply')",
#  '_i4': 'globals()'}

# %% [markdown]
# ### Global and Local scope

# %%
message = 'Some global data'
varA = 2

def function1(varA, varB):
    print('varA: ', varA)
    print(message)
    print(locals())

def function2(varC, varB):
    print('varA: ', varA)
    print(locals())

function1(1, 2)
function2(3, 4)
# Out:
# varA:  1
# Some global data
# {'varA': 1, 'varB': 2}
# varA:  2
# {'varC': 3, 'varB': 4}

# %%
def function1(varA, varB):
    message = 'Some local data'
    print(varA)
    
    def inner_function(varA, varB):
        print(f'inner_function local scope: {locals()}')

    print(locals())
    inner_function(123, 456)

function1(1, 2)
# Out:
# 1
# {'varA': 1, 'varB': 2, 'message': 'Some local data', 'inner_function': <function function1.<locals>.inner_function at 0x108b3df80>}
# inner_function local scope: {'varA': 123, 'varB': 456}
