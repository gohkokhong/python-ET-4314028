# %% [markdown]
# ### Bytes

# %%
bytes(4)
# Out:
# b'\x00\x00\x00\x00'

# %%
smileyBytes = bytes('🙄', 'utf-8')
smileyBytes
# Out:
# b'\xf0\x9f\x99\x84'

# %%
smileyBytes.decode('utf-8')
# Out:
# '🙄'

# %%
smileyBytes = bytearray('🙄', 'utf-8')	# "Byte" that can be modified
smileyBytes
# Out:
# bytearray(b'\xf0\x9f\x99\x84')

# %%
smileyBytes[3] = int('85', 16)
smileyBytes.decode('utf-8')
# Out:
# '🙅'
