# %% [markdown]
# ## Functions

# %%
print('Hello, World!')
# Out:
# Hello, World!

# %%
def multiplyByThree(val):
    return val * 3

multiplyByThree(9)
# Out:
# 27

# %%
def multiply(val, val2):
    return val * val2

multiply(3, 4)
# Out:
# 12

# %%
a = [1,2,3]

def appendFour(myList):
    myList.append(4)

appendFour(a)
print(a)
# Out:
# [1, 2, 3, 4]

# %%
print(print("abc"))
# Out:
# abc
# None

# %%
type(None)
# Out:
# NoneType
